# %% [markdown]
# To try - use different model architecture for two augmentation.
#
# v31 - Using switch value in the for loop with two different get_model function inorder to dynamically change the loss value based on the switch and augmentation method.
#
# V28,29,30 - Rerun which was a failure.
#
#
# v27 - Included rotation augmentation and based on random values , augmentation is performed for every epoch . Changed architecture from B6 to B5 . Increased folds from 3 to 5 and epochs from 10 to 15.
#
# v26 - Same config . Run for  3 folds. cv - 0.9723 LB - 0.95007
#
# v22 - Increasing the probability of cutmix from 0.8 to 1 , changing the model from efficientnet B5 to B6 .Epochs increased from 3 to 5.
#
# V20: Reduced epochs from 15 to 10 ,number of folds from 5 to 3,batch size removed from 32 to 16 and removed the reduce learning rate on plateau .CV -0.9842  LB=0.95611
#
# V19: Adding external data -Oxford flowers TF record dataset by Chris to increase the training dataset. CV - 0.98358  LB - 0.95470
#
# V18:Adding generalized mean pooling with custom head inspired by [this](https://www.kaggle.com/bamps53/private0-9704-tpu-keras-metric-learning) kernel.  CV - 0.9620 , LB - 0.94552

# %%
# !pip install -q efficientnet

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
import keras
from keras import backend as K
# from tensorflow.keras import initializers
# from tensorflow.keras import regularizers
# from tensorflow.keras import constraints
# from keras.engine import Layer, InputSpec
import random
#import tensorflow_addons as tfa
import matplotlib.pyplot as plt
from kaggle_datasets import KaggleDatasets
import efficientnet.tfkeras as efn
import albumentations
from sklearn.metrics import f1_score,confusion_matrix,precision_score,recall_score
from sklearn.model_selection import KFold,StratifiedKFold
print(f'Tensorflow version {tf.__version__}')
from tqdm import tqdm

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import math,re,os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.



def seed_everything(seed=0):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    
seed_everything(seed=101)
# Out:
# Using TensorFlow backend.
# Tensorflow version 2.1.0

# %% [markdown]
# From Starter Kernel , all the below codes:

# %%
AUTO = tf.data.experimental.AUTOTUNE
## Check if tpu is available:
try:
    tpu=tf.distribute.cluster_resolver.TPUClusterResolver()
    print("Running on TPU",tpu.master())
except ValueError:
    tpu=None
    
    
if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS:  8

# %%
MIXED_PRECISION = True
XLA_ACCELERATE = True

if MIXED_PRECISION:
    from tensorflow.keras.mixed_precision import experimental as mixed_precision
    if tpu: policy = tf.keras.mixed_precision.experimental.Policy('mixed_bfloat16')
    else: policy = tf.keras.mixed_precision.experimental.Policy('mixed_float16')
    mixed_precision.set_policy(policy)
    print('Mixed precision enabled')

if XLA_ACCELERATE:
    tf.config.optimizer.set_jit(True)
    print('Accelerated Linear Algebra enabled')
# Out:
# Mixed precision enabled
# Accelerated Linear Algebra enabled

# %%
## Check the files stored:
# !ls /kaggle/input
# Out:
# flower-classification-with-tpus  oxford-flowers-tfrecords

# %%
## Competition data:
GCS_DS_PATH = KaggleDatasets().get_gcs_path('flower-classification-with-tpus') # you can list the bucket with "!gsutil ls $GCS_DS_PATH"
print(GCS_DS_PATH)
OX_GCS_DS_PATH=KaggleDatasets().get_gcs_path('oxford-flowers-tfrecords')
print(OX_GCS_DS_PATH)
# Out:
# gs://kds-a44744780cb28b908f65e7fa3b4a473ef199bb9ffe8048dbbf29ffeb
# gs://kds-101ff64c49e8bf50925e5ecc56fb0fd794d58a10db1d8ad37f6e5fc6

# %%
## For efficientnet:

IMAGE_SIZE=[512,512]
EPOCHS=15##  
BATCH_SIZE=16*strategy.num_replicas_in_sync
AUG_BATCH = BATCH_SIZE

# %%
## Reading competition data:
GCS_PATH_SELECT = { # available image sizes
    192: GCS_DS_PATH + '/tfrecords-jpeg-192x192',
    224: GCS_DS_PATH + '/tfrecords-jpeg-224x224',
    331: GCS_DS_PATH + '/tfrecords-jpeg-331x331',
    512: GCS_DS_PATH + '/tfrecords-jpeg-512x512'
}
GCS_PATH=GCS_PATH_SELECT[IMAGE_SIZE[0]]
GCS_PATH
# Out:
# 'gs://kds-a44744780cb28b908f65e7fa3b4a473ef199bb9ffe8048dbbf29ffeb/tfrecords-jpeg-512x512'

# %%
# !gsutil ls $GCS_PATH
# Out:
# gs://kds-a44744780cb28b908f65e7fa3b4a473ef199bb9ffe8048dbbf29ffeb/tfrecords-jpeg-512x512/test/
# gs://kds-a44744780cb28b908f65e7fa3b4a473ef199bb9ffe8048dbbf29ffeb/tfrecords-jpeg-512x512/train/
# gs://kds-a44744780cb28b908f65e7fa3b4a473ef199bb9ffe8048dbbf29ffeb/tfrecords-jpeg-512x512/val/

# %%
## Reading oxford data:
OX_GCS_PATH_SELECT = { # available image sizes
    192: OX_GCS_DS_PATH + '/tfrecords-png-192x192',
    224: OX_GCS_DS_PATH + '/tfrecords-png-224x224',
    331: OX_GCS_DS_PATH + '/tfrecords-png-331x331',
    512: OX_GCS_DS_PATH + '/tfrecords-png-512x512'
}
OX_GCS_PATH=OX_GCS_PATH_SELECT[IMAGE_SIZE[0]]
OX_GCS_PATH
# Out:
# 'gs://kds-101ff64c49e8bf50925e5ecc56fb0fd794d58a10db1d8ad37f6e5fc6/tfrecords-png-512x512'

# %%
# !gsutil ls $OX_GCS_PATH
# Out:
# gs://kds-101ff64c49e8bf50925e5ecc56fb0fd794d58a10db1d8ad37f6e5fc6/tfrecords-png-512x512/00-512x512-819.tfrec
# gs://kds-101ff64c49e8bf50925e5ecc56fb0fd794d58a10db1d8ad37f6e5fc6/tfrecords-png-512x512/01-512x512-819.tfrec
# gs://kds-101ff64c49e8bf50925e5ecc56fb0fd794d58a10db1d8ad37f6e5fc6/tfrecords-png-512x512/02-512x512-819.tfrec
# gs://kds-101ff64c49e8bf50925e5ecc56fb0fd794d58a10db1d8ad37f6e5fc6/tfrecords-png-512x512/03-512x512-819.tfrec
# gs://kds-101ff64c49e8bf50925e5ecc56fb0fd794d58a10db1d8ad37f6e5fc6/tfrecords-png-512x512/04-512x512-819.tfrec
# gs://kds-101ff64c49e8bf50925e5ecc56fb0fd794d58a10db1d8ad37f6e5fc6/tfrecords-png-512x512/05-512x512-819.tfrec
# gs://kds-101ff64c49e8bf50925e5ecc56fb0fd794d58a10db1d8ad37f6e5fc6/tfrecords-png-512x512/06-512x512-819.tfrec
# gs://kds-101ff64c49e8bf50925e5ecc56fb0fd794d58a10db1d8ad37f6e5fc6/tfrecords-png-512x512/07-512x512-819.tfrec
# gs://kds-101ff64c49e8bf50925e5ecc56fb0fd794d58a10db1d8ad37f6e5fc6/tfrecords-png-512x512/08-512x512-819.tfrec
# gs://kds-101ff64c49e8bf50925e5ecc56fb0fd794d58a10db1d8ad37f6e5fc6/tfrecords-png-512x512/09-512x512-818.tfrec

# %%
## Join the oxford dataset in the training :
OX_TRAINING_FILENAMES=tf.io.gfile.glob(OX_GCS_PATH+"/*.tfrec")
TRAINING_FILENAMES=tf.io.gfile.glob(GCS_PATH+"/train/*.tfrec")+tf.io.gfile.glob(OX_GCS_PATH+"/*.tfrec")
VALIDATION_FILENAMES=tf.io.gfile.glob(GCS_PATH+"/val/*.tfrec")
TEST_FILENAMES=tf.io.gfile.glob(GCS_PATH+"/test/*.tfrec")

# %%
CLASSES = ['pink primrose',    'hard-leaved pocket orchid', 'canterbury bells', 'sweet pea',     'wild geranium',     'tiger lily',           'moon orchid',              'bird of paradise', 'monkshood',        'globe thistle',         # 00 - 09
           'snapdragon',       "colt's foot",               'king protea',      'spear thistle', 'yellow iris',       'globe-flower',         'purple coneflower',        'peruvian lily',    'balloon flower',   'giant white arum lily', # 10 - 19
           'fire lily',        'pincushion flower',         'fritillary',       'red ginger',    'grape hyacinth',    'corn poppy',           'prince of wales feathers', 'stemless gentian', 'artichoke',        'sweet william',         # 20 - 29
           'carnation',        'garden phlox',              'love in the mist', 'cosmos',        'alpine sea holly',  'ruby-lipped cattleya', 'cape flower',              'great masterwort', 'siam tulip',       'lenten rose',           # 30 - 39
           'barberton daisy',  'daffodil',                  'sword lily',       'poinsettia',    'bolero deep blue',  'wallflower',           'marigold',                 'buttercup',        'daisy',            'common dandelion',      # 40 - 49
           'petunia',          'wild pansy',                'primula',          'sunflower',     'lilac hibiscus',    'bishop of llandaff',   'gaura',                    'geranium',         'orange dahlia',    'pink-yellow dahlia',    # 50 - 59
           'cautleya spicata', 'japanese anemone',          'black-eyed susan', 'silverbush',    'californian poppy', 'osteospermum',         'spring crocus',            'iris',             'windflower',       'tree poppy',            # 60 - 69
           'gazania',          'azalea',                    'water lily',       'rose',          'thorn apple',       'morning glory',        'passion flower',           'lotus',            'toad lily',        'anthurium',             # 70 - 79
           'frangipani',       'clematis',                  'hibiscus',         'columbine',     'desert-rose',       'tree mallow',          'magnolia',                 'cyclamen ',        'watercress',       'canna lily',            # 80 - 89
           'hippeastrum ',     'bee balm',                  'pink quill',       'foxglove',      'bougainvillea',     'camellia',             'mallow',                   'mexican petunia',  'bromelia',         'blanket flower',        # 90 - 99
           'trumpet creeper',  'blackberry lily',           'common tulip',     'wild rose']                                                                                                                                               # 100 - 102

# %%
np.set_printoptions(threshold=15, linewidth=80)

def batch_to_numpy_images_and_labels(data):
    images,labels=data
    numpy_images = images.numpy()
    numpy_labels = labels.numpy()
    if numpy_labels.dtype == object: # binary string in this case, these are image ID strings
        numpy_labels = [None for _ in enumerate(numpy_images)]
    # If no labels, only image IDs, return None for labels (this is the case for test data)
    return numpy_images, numpy_labels

def title_from_label_and_target(label, correct_label):
    if correct_label is None:
        return CLASSES[label], True
    correct = (label == correct_label)
    return "{} [{}{}{}]".format(CLASSES[label], 'OK' if correct else 'NO', u"\u2192" if not correct else '',
                                CLASSES[correct_label] if not correct else ''), correct

def display_one_flower(image, title, subplot, red=False, titlesize=16):
    plt.subplot(*subplot)
    plt.axis('off')
    plt.imshow(image)
    if len(title) > 0:
        plt.title(title, fontsize=int(titlesize) if not red else int(titlesize/1.2), color='red' if red else 'black', fontdict={'verticalalignment':'center'}, pad=int(titlesize/1.5))
    return (subplot[0], subplot[1], subplot[2]+1)
    
def display_batch_of_images(databatch, predictions=None):
    """This will work with:
    display_batch_of_images(images)
    display_batch_of_images(images, predictions)
    display_batch_of_images((images, labels))
    display_batch_of_images((images, labels), predictions)
    """
    # data
    images, labels = batch_to_numpy_images_and_labels(databatch)
    if labels is None:
        labels = [None for _ in enumerate(images)]
        
    # auto-squaring: this will drop data that does not fit into square or square-ish rectangle
    rows = int(math.sqrt(len(images)))
    cols = len(images)//rows
        
    # size and spacing
    FIGSIZE = 13.0
    SPACING = 0.1
    subplot=(rows,cols,1)
    if rows < cols:
        plt.figure(figsize=(FIGSIZE,FIGSIZE/cols*rows))
    else:
        plt.figure(figsize=(FIGSIZE/rows*cols,FIGSIZE))
    
    # display
    for i, (image, label) in enumerate(zip(images[:rows*cols], labels[:rows*cols])):
        title = '' if label is None else CLASSES[label]
        correct = True
        if predictions is not None:
            title, correct = title_from_label_and_target(predictions[i], label)
        dynamic_titlesize = FIGSIZE*SPACING/max(rows,cols)*40+3 # magic formula tested to work from 1x1 to 10x10 images
        subplot = display_one_flower(image, title, subplot, not correct, titlesize=dynamic_titlesize)
    
    #layout
    plt.tight_layout()
    if label is None and predictions is None:
        plt.subplots_adjust(wspace=0, hspace=0)
    else:
        plt.subplots_adjust(wspace=SPACING, hspace=SPACING)
    plt.show()
    
def display_confusion_matrix(cmat, score, precision, recall):
    plt.figure(figsize=(15,15))
    ax = plt.gca()
    ax.matshow(cmat, cmap='Reds')
    ax.set_xticks(range(len(CLASSES)))
    ax.set_xticklabels(CLASSES, fontdict={'fontsize': 7})
    plt.setp(ax.get_xticklabels(), rotation=45, ha="left", rotation_mode="anchor")
    ax.set_yticks(range(len(CLASSES)))
    ax.set_yticklabels(CLASSES, fontdict={'fontsize': 7})
    plt.setp(ax.get_yticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    titlestring = ""
    if score is not None:
        titlestring += 'f1 = {:.3f} '.format(score)
    if precision is not None:
        titlestring += '\nprecision = {:.3f} '.format(precision)
    if recall is not None:
        titlestring += '\nrecall = {:.3f} '.format(recall)
    if len(titlestring) > 0:
        ax.text(101, 1, titlestring, fontdict={'fontsize': 18, 'horizontalalignment':'right', 'verticalalignment':'top', 'color':'#804040'})
    plt.show()
    
def display_training_curves(training, validation, title, subplot):
    if subplot%10==1: # set up the subplots on the first call
        plt.subplots(figsize=(10,10), facecolor='#F0F0F0')
        plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model '+ title)
    ax.set_ylabel(title)
    #ax.set_ylim(0.28,1.05)
    ax.set_xlabel('epoch')
    ax.legend(['train', 'valid.'])

# %%
def decode_image(image_data):
    image = tf.image.decode_jpeg(image_data, channels=3)
    image = tf.cast(image, tf.float32) / 255.0  # convert image to floats in [0, 1] range
    image = tf.reshape(image, [*IMAGE_SIZE, 3]) # explicit size needed for TPU
    return image

def read_labeled_tfrecord(example):
    LABELED_TFREC_FORMAT = {
        "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
        "class": tf.io.FixedLenFeature([], tf.int64),  # shape [] means single element
    }
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'])
    label = tf.cast(example['class'], tf.int32)
    return image, label # returns a dataset of (image, label) pairs

def read_unlabeled_tfrecord(example):
    UNLABELED_TFREC_FORMAT = {
        "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
        "id": tf.io.FixedLenFeature([], tf.string),  # shape [] means single element
        # class is missing, this competitions's challenge is to predict flower classes for the test dataset
    }
    example = tf.io.parse_single_example(example, UNLABELED_TFREC_FORMAT)
    image = decode_image(example['image'])
    idnum = example['id']
    return image, idnum # returns a dataset of image(s)

def load_dataset(filenames, labeled=True, ordered=False):
    # Read from TFRecords. For optimal performance, reading from multiple files at once and
    # disregarding data order. Order does not matter since we will be shuffling the data anyway.

    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False # disable order, increase speed

    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTO) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(read_labeled_tfrecord if labeled else read_unlabeled_tfrecord, num_parallel_calls=AUTO)
    # returns a dataset of (image, label) pairs if labeled=True or (image, id) pairs if labeled=False
    return dataset



def data_augment(image, label):
    # data augmentation. Thanks to the dataset.prefetch(AUTO) statement in the next function (below),
    # this happens essentially for free on TPU. Data pipeline code is executed on the "CPU" part
    # of the TPU while the TPU itself is computing gradients.
    #image = tf.image.random_contrast(image,lower=0.3,upper=0.5,seed=101)
    #image = tf.image.random_brightness(image, 0.1, seed=SEED)
    image = tf.image.resize(image, [456,456])
    #image = tf.image.resize(image, [299,299])  # inception_resnet_v2
    #image = tf.image.random_saturation(image, 0, 2)
    return image, label   

def data_augment_valid(image, label):
    #image = tf.image.resize(image, [300, 300])
    image = tf.image.resize(image, [456,456])
    return image, label   
def data_augment_test(image, idnum):
    #image = tf.image.resize(image, [300, 300])
    image = tf.image.resize(image, [456,456])
    return image,idnum

def get_training_dataset(dataset,switch,do_aug=False):
    #dataset = load_dataset(TRAINING_FILENAMES, labeled=True)
    #dataset=dataset.map()
    #dataset=dataset.map(data_augment, num_parallel_calls=AUTO)
    #switch = np.random.randn()
    if do_aug:
        if switch >=0.5: 
            print(f'Training:Doing cutmix augmentation for switch value {switch}')
            dataset=dataset.repeat()
            dataset=dataset.batch(AUG_BATCH)
            dataset = dataset.map(cutmix_augment,num_parallel_calls=AUTO)
            dataset=dataset.unbatch()
        elif switch <0.5: 
            print(f'Training:Doing rotation transformation for switch value {switch}')
            dataset = dataset.map(transform,num_parallel_calls=AUTO)
            dataset=dataset.repeat()
    ## Perform random augmentation:
    #if do_cm:dataset=dataset.map(batch_cutmix,num_parallel_calls=AUTO)
    #if do_aug:dataset=dataset.map(data_augment,num_parallel_calls=AUTO)
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_validation_dataset(dataset,switch,do_onehot=False,do_aug=False):
    #dataset = load_dataset(VALIDATION_FILENAMES, labeled=True, ordered=ordered)
    dataset = dataset.batch(BATCH_SIZE)
    if do_onehot:dataset=dataset.map(one_hot_encode,num_parallel_calls=AUTO)
    #switch = np.random.randint(50)
#     if do_aug:
#         if switch <=25 : 
#             print(f'Validation:Doing cutmix augmentation for switch value {switch}')
#             dataset = dataset.map(cutmix_augment,num_parallel_calls=AUTO)
#         elif switch <25 : 
#             print(f'Validation:Doing rotation transformation for switch value {switch}')
#             dataset = dataset.map(transform,num_parallel_calls=AUTO)    
    #if do_aug:dataset=dataset.map(data_augment,num_parallel_calls=AUTO)
    dataset = dataset.cache()
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def get_test_dataset(ordered=False,do_aug=False):
    dataset = load_dataset(TEST_FILENAMES, labeled=False, ordered=ordered)
    if do_aug:dataset=dataset.map(data_augment,num_parallel_calls=AUTO)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO) # prefetch next batch while training (autotune prefetch buffer size)
    return dataset

def count_data_items(filenames):
    # the number of data items is written in the name of the .tfrec files, i.e. flowers00-230.tfrec = 230 data items
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) for filename in filenames]
    return np.sum(n)

# %%
NUM_TRAINING_IMAGES = count_data_items(TRAINING_FILENAMES)
NUM_OX_TRAINING_IMAGES=count_data_items(OX_TRAINING_FILENAMES)
NUM_VALIDATION_IMAGES = count_data_items(VALIDATION_FILENAMES)
NUM_TEST_IMAGES = count_data_items(TEST_FILENAMES)
STEPS_PER_EPOCH = NUM_TRAINING_IMAGES // BATCH_SIZE
print('Dataset: {} training images,{} in oxford training images, {} validation images, {} unlabeled test images,{} Steps per epoch '.format(NUM_TRAINING_IMAGES,NUM_OX_TRAINING_IMAGES, NUM_VALIDATION_IMAGES, NUM_TEST_IMAGES,STEPS_PER_EPOCH))
# Out:
# Dataset: 20942 training images,8189 in oxford training images, 3712 validation images, 7382 unlabeled test images,163 Steps per epoch

# %% [markdown]
# From Dataset: 12753 training images, 3712 validation images, 7382 unlabeled test images,49 Steps per epoch  without using the external data, there is a extra 8189 flowers in train dataset.Lets train now with this increased data.

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# Inspiration - [Chris kernel](https://www.kaggle.com/cdeotte/cutmix-and-mixup-on-gpu-tpu)

# %% [markdown]
# LR scheduler from this kernel [Learning Rate Scheduler Code](https://www.kaggle.com/xhlulu/flowers-tpu-concise-efficientnet-b7)

# %%
 #Learning rate schedule for TPU, GPU and CPU.
# Using an LR ramp up because fine-tuning a pre-trained model.
# Starting with a high LR would break the pre-trained weights.

LR_START = 0.00001
LR_MAX = 0.00005 * strategy.num_replicas_in_sync
LR_MIN = 0.00001
LR_RAMPUP_EPOCHS = 5
LR_SUSTAIN_EPOCHS = 0
LR_EXP_DECAY = .8

def lrfn(epoch):
    if epoch < LR_RAMPUP_EPOCHS:
        lr = (LR_MAX - LR_START) / LR_RAMPUP_EPOCHS * epoch + LR_START
    elif epoch < LR_RAMPUP_EPOCHS + LR_SUSTAIN_EPOCHS:
        lr = LR_MAX
    else:
        lr = (LR_MAX - LR_MIN) * LR_EXP_DECAY**(epoch - LR_RAMPUP_EPOCHS - LR_SUSTAIN_EPOCHS) + LR_MIN
    return lr
    
lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose = True)

rng = [i for i in range(25 if EPOCHS<25 else EPOCHS)]
y = [lrfn(x) for x in rng]
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-05 to 0.0004 to 1.56e-05

# %% [markdown]
# ## Rotation Augmentation

# %%
def get_mat(rotation, shear, height_zoom, width_zoom, height_shift, width_shift):
    # returns 3x3 transformmatrix which transforms indicies
        
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    shear = math.pi * shear / 180.
    
    # ROTATION MATRIX
    c1 = tf.math.cos(rotation)
    s1 = tf.math.sin(rotation)
    one = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    rotation_matrix = tf.reshape( tf.concat([c1,s1,zero, -s1,c1,zero, zero,zero,one],axis=0),[3,3] )
        
    # SHEAR MATRIX
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)
    shear_matrix = tf.reshape( tf.concat([one,s2,zero, zero,c2,zero, zero,zero,one],axis=0),[3,3] )    
    
    # ZOOM MATRIX
    zoom_matrix = tf.reshape( tf.concat([one/height_zoom,zero,zero, zero,one/width_zoom,zero, zero,zero,one],axis=0),[3,3] )
    
    # SHIFT MATRIX
    shift_matrix = tf.reshape( tf.concat([one,zero,height_shift, zero,one,width_shift, zero,zero,one],axis=0),[3,3] )
    
    return K.dot(K.dot(rotation_matrix, shear_matrix), K.dot(zoom_matrix, shift_matrix))

# %%
def transform(image,label):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated, sheared, zoomed, and shifted
    DIM = IMAGE_SIZE[0]
    XDIM = DIM%2 #fix for size 331
    
    rot = 15. * tf.random.normal([1],dtype='float32')
    shr = 5. * tf.random.normal([1],dtype='float32') 
    h_zoom = 1.0 + tf.random.normal([1],dtype='float32')/10.
    w_zoom = 1.0 + tf.random.normal([1],dtype='float32')/10.
    h_shift = 16. * tf.random.normal([1],dtype='float32') 
    w_shift = 16. * tf.random.normal([1],dtype='float32') 
  
    # GET TRANSFORMATION MATRIX
    m = get_mat(rot,shr,h_zoom,w_zoom,h_shift,w_shift) 

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(m,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES           
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image,tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,3]),label

# %% [markdown]
# ## Cut Mix Augmentation

# %% [markdown]
# Basic Idea from [Chris's](https://www.kaggle.com/cdeotte/cutmix-and-mixup-on-gpu-tpu) kernel . Research paper in [Arxiv](https://arxiv.org/abs/1905.04899)

# %% [markdown]
# For the cut mix to work , we need to convert the labels into one hot encoding.

# %%
def one_hot_encode(image,label):
    CLASSES=104
    return image,tf.one_hot(label,CLASSES)

# %%
# tf.cast(BATCH_SIZE*tf.math.sqrt(1-0.1),tf.int32)

# %%
def cutmix_augment(image,label,prob=1):  # Change the prob of cutmix here
    DIM=IMAGE_SIZE[0]
    CLASSES=104
    
    imgs=[];labs=[]
    for j in range(AUG_BATCH):
        # Generate the probability:
        P=tf.cast(tf.random.uniform([],0,1)<=prob,tf.int32)
        #Generate a random image:
        K=tf.cast(tf.random.uniform([],0,AUG_BATCH),tf.int32)
        #Generate x,y coordinates:
        x=tf.cast(tf.random.uniform([],0,DIM),tf.int32)
        y=tf.cast(tf.random.uniform([],0,DIM),tf.int32)
        #beta distribution:
        b=tf.random.uniform([],0,1)
        WIDTH=tf.cast(DIM*tf.math.sqrt(1-b),tf.int32)*P
        ya=tf.math.maximum(0,y-WIDTH//2)
        yb=tf.math.minimum(DIM,y+WIDTH//2)
        xa=tf.math.maximum(0,x-WIDTH//2)
        xb=tf.math.minimum(DIM,x+WIDTH//2)
        
        ##Make Cut Mix Image:
        one=image[j,ya:yb,0:xa,:]   #images of size [n,dim,dim,3]
        two=image[K,ya:yb,xa:xb,:]
        three=image[j,ya:yb,xb:DIM,:]
        middle=tf.concat([one,two,three],axis=1)
        img=tf.concat([image[j,0:ya,:,:],middle,image[j,yb:DIM,:,:]],axis=0)
        imgs.append(img)
        ## Make the cutmix label:
        a=tf.cast(WIDTH*WIDTH/DIM/DIM,tf.float32)
        
        if len(label.shape)==1:
            lab1=tf.one_hot(label[j],CLASSES)
            lab2=tf.one_hot(label[K],CLASSES)
        
        else:
            lab1=label[j,]
            lab2=label[K,]
        labs.append((1-a)*lab1 + a*lab2)
        
        
    image2=tf.reshape(tf.stack(imgs),(AUG_BATCH,DIM,DIM,3))
    label2=tf.reshape(tf.stack(labs),(AUG_BATCH,CLASSES))
    return image2,label2

# %%
## Implementation of batch cutmix function from kernel - https://www.kaggle.com/yihdarshieh/batch-implementation-of-more-data-augmentations/notebook?scriptVersionId=29767726#Batch-CutMix
def batch_cutmix(images, labels, PROBABILITY=1, batch_size=AUG_BATCH):
    
    DIM = IMAGE_SIZE[0]
    CLASSES = 104
    
    if batch_size == 0:
        batch_size = BATCH_SIZE
    
    # DO CUTMIX WITH PROBABILITY DEFINED ABOVE
    # This is a tensor containing 0 or 1 -- 0: no cutmix.
    # shape = [batch_size]
    do_cutmix = tf.cast(tf.random.uniform([batch_size], 0, 1) <= PROBABILITY, tf.int32)
    
    # Choose random images in the batch for cutmix
    # shape = [batch_size]
    new_image_indices = tf.cast(tf.random.uniform([batch_size], 0, batch_size), tf.int32)
    
    # Choose random location in the original image to put the new images
    # shape = [batch_size]
    new_x = tf.cast(tf.random.uniform([batch_size], 0, DIM), tf.int32)
    new_y = tf.cast(tf.random.uniform([batch_size], 0, DIM), tf.int32)
    
    # Random width for new images, shape = [batch_size]
    b = tf.random.uniform([batch_size], 0, 1) # this is beta dist with alpha=1.0
    new_width = tf.cast(DIM * tf.math.sqrt(1-b), tf.int32) * do_cutmix
    
    # shape = [batch_size]
    new_y0 = tf.math.maximum(0, new_y - new_width // 2)
    new_y1 = tf.math.minimum(DIM, new_y + new_width // 2)
    new_x0 = tf.math.maximum(0, new_x - new_width // 2)
    new_x1 = tf.math.minimum(DIM, new_x + new_width // 2)
    
    # shape = [batch_size, DIM]
    target = tf.broadcast_to(tf.range(DIM), shape=(batch_size, DIM))
    
    # shape = [batch_size, DIM]
    mask_y = tf.math.logical_and(new_y0[:, tf.newaxis] <= target, target <= new_y1[:, tf.newaxis])
    
    # shape = [batch_size, DIM]
    mask_x = tf.math.logical_and(new_x0[:, tf.newaxis] <= target, target <= new_x1[:, tf.newaxis])    
    
    # shape = [batch_size, DIM, DIM]
    mask = tf.cast(tf.math.logical_and(mask_y[:, :, tf.newaxis], mask_x[:, tf.newaxis, :]), tf.float32)

    # All components are of shape [batch_size, DIM, DIM, 3]
    new_images =  images * tf.broadcast_to(1 - mask[:, :, :, tf.newaxis], [batch_size, DIM, DIM, 3]) + \
                    tf.gather(images, new_image_indices) * tf.broadcast_to(mask[:, :, :, tf.newaxis], [batch_size, DIM, DIM, 3])

    a = tf.cast(new_width ** 2 / DIM ** 2, tf.float32)    
        
    # Make labels
    if len(labels.shape) == 1:
        labels = tf.one_hot(labels, CLASSES)
        
    new_labels =  (1-a)[:, tf.newaxis] * labels + a[:, tf.newaxis] * tf.gather(labels, new_image_indices)        
        
    return new_images, new_labels

# %% [markdown]
# ## Check how the augmentation works:

# %%
# row = 3; col = 4;
# all_elements = get_training_dataset(load_dataset(TRAINING_FILENAMES),do_aug=False).unbatch()
# one_element = tf.data.Dataset.from_tensors( next(iter(all_elements)) )
# switch=np.random.randint(50)
# print(f'Switch value {switch}')
# if switch<=25: augmented_element=all_elements.repeat().batch(AUG_BATCH).map(cutmix_augment)
# elif switch>25:augmented_element=one_element.repeat().map(transform).batch(row*col)
# #augmented_element = one_element.repeat().map(transform).batch(row*col)

# for (img,label) in augmented_element:
#     plt.figure(figsize=(15,int(15*row/col)))
#     for j in range(row*col):
#         plt.subplot(row,col,j+1)
#         plt.axis('off')
#         plt.imshow(img[j,])
#     plt.show()
#     break

# %%
# rows=5
# cols=5

# rows=min(rows,AUG_BATCH//cols)
# all_elements=get_training_dataset(load_dataset(TRAINING_FILENAMES),do_cm=False).unbatch()

# #augmented_elements=all_elements.repeat().batch(AUG_BATCH).map(cutmix_augment)
# augmented_elements=all_elements.repeat().batch(AUG_BATCH).map(batch_cutmix)

# %%
# for (img,label) in augmented_elements:
#     plt.figure(figsize=(15,int(15*rows/cols)))
#     for j in range(rows*cols):
#         plt.subplot(rows,cols,j+1)
#         plt.axis('off')
#         #print(img[j,].numpy().shape)
#         plt.imshow(img[j,])
#         #print(CLASSES[label[j]])
#     plt.show()
#     break

# %%
# for (img,label) in augmented_elements.take(1):
#     print(img.numpy().shape,label.numpy().shape)
#     print(type(label),type(label.numpy()))
#     print(label[1].numpy())

# %% [markdown]
# # Modelling

# %%
class Generalized_mean_pooling2D(tf.keras.layers.Layer):
    def __init__(self, p=3, epsilon=1e-6, name='', **kwargs):
      super(Generalized_mean_pooling2D, self).__init__(name, **kwargs)
      self.init_p = p
      self.epsilon = epsilon
    
    def build(self, input_shape):
      if isinstance(input_shape, list) or len(input_shape) != 4:
        raise ValueError('`GeM` pooling layer only allow 1 input with 4 dimensions(b, h, w, c)')
      self.build_shape = input_shape
      self.p = self.add_weight(
              name='p',
              shape=[1,],
              initializer=tf.keras.initializers.Constant(value=self.init_p),
              regularizer=None,
              trainable=True,
              dtype=tf.float32
              )
      self.built=True

    def call(self, inputs):
      input_shape = inputs.get_shape()
      if isinstance(inputs, list) or len(input_shape) != 4:
        raise ValueError('`GeM` pooling layer only allow 1 input with 4 dimensions(b, h, w, c)')
      return (tf.reduce_mean(tf.abs(inputs**self.p), axis=[1,2], keepdims=False) + self.epsilon)**(1.0/self.p)

# %%
# def get_model():

#     with strategy.scope():
#         pretrained_model=tf.keras.applications.inception_resnet_v2.InceptionResNetV2(input_shape=(512,512,3),include_top=False,weights="imagenet")
#         #pretrained_model.trainable = False # Removing the pretrained weights since pretrained weights give an categorical accuracy of max 0.34 . 
#         model=tf.keras.Sequential([pretrained_model,
#                                    #tf.keras.layers.GlobalAveragePooling2D(),
#                                    tf.keras.layers.GlobalMaxPool2D(),
#                                    #tf.keras.layers.Dropout(0.3),
#                                    #tf.keras.layers.Dense(1024,activation='elu'),
#                                    #tf.keras.layers.Dropout(0.4),
#                                   tf.keras.layers.Dense(len(CLASSES),activation="softmax",dtype='float32')])
#         #es=tf.keras.callbacks.EarlyStopping(monitor='val_loss',mode='auto',patience=5,verbose=1)
#         #rlr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=5,verbose=1,mode='min',epsilon=0.0001)
#     # lr_scheduler=tfa.optimizers.CyclicalLearningRate(initial_learning_rate=5e-5,
#     #                                                 maximal_learning_rate=6e-3,
#     #                                                 step_size=200,
#     #                                                 scale_fn=lambda x:1.,
#     #                                                 scale_mode="cycle",
#     #                                                 name="cyclic_learning_rate")

#     model.compile(
#         optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
#         loss = 'categorical_crossentropy',
#         metrics=['categorical_accuracy']
#     )
#     return model

# %%
# model=efn.EfficientNetB5()
# model.summary()

# %%
def get_model():

    with strategy.scope():
        pretrained_model=efn.EfficientNetB5(input_shape=(512,512,3),include_top=False,weights="noisy-student") ## using noisy student weights instead of imagenet
        #pretrained_model.trainable = False 
        model=tf.keras.Sequential([pretrained_model,
                                   #Generalized_mean_pooling2D(),
                                   tf.keras.layers.GlobalAveragePooling2D(),
                                   #tf.keras.layers.GlobalMaxPool2D(),
                                   tf.keras.layers.Dropout(0.3),
                                   tf.keras.layers.Dense(1024,activation='relu'),
                                   #tf.keras.layers.Dropout(0.4),
                                  tf.keras.layers.Dense(len(CLASSES),activation="softmax",dtype='float32')])
        #es=tf.keras.callbacks.EarlyStopping(monitor='val_loss',mode='auto',patience=5,verbose=1)
        #rlr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=5,verbose=1,mode='min',epsilon=0.0001)
    # lr_scheduler=tfa.optimizers.CyclicalLearningRate(initial_learning_rate=5e-5,
    #                                                 maximal_learning_rate=6e-3,
    #                                                 step_size=200,
    #                                                 scale_fn=lambda x:1.,
    #                                                 scale_mode="cycle",
    #                                                 name="cyclic_learning_rate")

    model.compile(
        optimizer='adam',
        loss = 'sparse_categorical_crossentropy',  ## for rotation augmentation require sparse_categorical crossentropy , for cutmix need categorical_crossentropy.
        metrics=['sparse_categorical_accuracy']
    )
    return model

# %%
def get_model_cm():

    with strategy.scope():
        pretrained_model=efn.EfficientNetB5(input_shape=(512,512,3),include_top=False,weights="noisy-student") ## using noisy student weights instead of imagenet
        #pretrained_model.trainable = False 
        model=tf.keras.Sequential([pretrained_model,
                                   #Generalized_mean_pooling2D(),
                                   tf.keras.layers.GlobalAveragePooling2D(),
                                   #tf.keras.layers.GlobalMaxPool2D(),
                                   tf.keras.layers.Dropout(0.3),
                                   tf.keras.layers.Dense(1024,activation='relu'),
                                   #tf.keras.layers.Dropout(0.4),
                                  tf.keras.layers.Dense(len(CLASSES),activation="softmax",dtype='float32')])
        #es=tf.keras.callbacks.EarlyStopping(monitor='val_loss',mode='auto',patience=5,verbose=1)
        #rlr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=5,verbose=1,mode='min',epsilon=0.0001)
    # lr_scheduler=tfa.optimizers.CyclicalLearningRate(initial_learning_rate=5e-5,
    #                                                 maximal_learning_rate=6e-3,
    #                                                 step_size=200,
    #                                                 scale_fn=lambda x:1.,
    #                                                 scale_mode="cycle",
    #                                                 name="cyclic_learning_rate")

    model.compile(
        optimizer='adam',
        loss = 'categorical_crossentropy',  ## for rotation augmentation require sparse_categorical crossentropy , for cutmix need categorical_crossentropy.
        metrics=['categorical_accuracy']
    )
    return model

# %% [markdown]
# # Training

# %%
np.random.normal()
# Out:
# 2.706849839399938

# %%
def train_model(folds=5):
    histories=[]
    models=[]
    all_preds=[]
    all_probs=[]
    scores=[]
    es=tf.keras.callbacks.EarlyStopping(monitor='val_loss',mode='auto',patience=3,verbose=1) ## reducing patience from 5 to 3
    rlr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=3,verbose=1,mode='min',epsilon=0.0001)
    k_folds=KFold(folds,shuffle=True,random_state=SEED)
    #model=get_model()
    #model.summary()
    for i,(trn_idx,val_idx) in enumerate(k_folds.split(TRAINING_FILENAMES)):
        print(f"---------------Folds {i+1}--------------")
        train_dataset=load_dataset(list(pd.DataFrame({'TRAINING_FILENAMES':TRAINING_FILENAMES}).loc[trn_idx]['TRAINING_FILENAMES']),labeled=True)
        
        valid_dataset=load_dataset(list(pd.DataFrame({'TRAINING_FILENAMES':TRAINING_FILENAMES}).loc[val_idx]['TRAINING_FILENAMES']),labeled=True,ordered=True)
        checkpoint_name=f'efficientnetb3_{i+1}'+'.h5'
        model_checkpoint=tf.keras.callbacks.ModelCheckpoint(checkpoint_name,save_best_only=True,save_weights_only=True)
        switch =np.random.normal()## Taking it here since one hot encoding is required for cut mix.
        if switch<0.5:
            model=get_model()
            history= model.fit(get_training_dataset(train_dataset,do_aug=True,switch=switch), steps_per_epoch=STEPS_PER_EPOCH, epochs=EPOCHS, validation_data=get_validation_dataset(valid_dataset,switch=switch),callbacks=[es,lr_callback,model_checkpoint])
        else:
            model=get_model_cm()
            history= model.fit(get_training_dataset(train_dataset,do_aug=True,switch=switch), steps_per_epoch=STEPS_PER_EPOCH, epochs=EPOCHS, validation_data=get_validation_dataset(valid_dataset,switch=switch,do_onehot=True,do_aug=True),callbacks=[es,lr_callback,model_checkpoint])
        #history= model.fit(get_training_dataset(train_dataset,do_aug=True,switch=switch), steps_per_epoch=STEPS_PER_EPOCH, epochs=EPOCHS, validation_data=get_validation_dataset(valid_dataset,switch=switch),callbacks=[es,lr_callback,model_checkpoint])
        NUM_VALID_IMAGES=count_data_items(list(pd.DataFrame({'TRAINING_FILENAMES':TRAINING_FILENAMES}).loc[val_idx]['TRAINING_FILENAMES']))
        #print(f'Loading best weights for epoch {i+1}')
        #model.load_weights(checkpoint_name)
        models.append(model)
        histories.append(history)
        cmdataset = get_validation_dataset(valid_dataset,switch=switch)
        images_ds = cmdataset.map(lambda image, label: image)
        labels_ds = cmdataset.map(lambda image, label: label).unbatch()
        
        cm_correct_labels = next(iter(labels_ds.batch(NUM_VALID_IMAGES))).numpy() # get everything as one batch
        cm_probabilities = model.predict(images_ds)
        cm_predictions = np.argmax(cm_probabilities, axis=-1)

       # cmat = confusion_matrix(cm_correct_labels, cm_predictions, labels=range(len(CLASSES)))
        score = f1_score(cm_correct_labels, cm_predictions, labels=range(len(CLASSES)), average='macro')
        scores.append(score)
        print(f"Macro F1 Score for epoch {i+1}:",score)
#         print(f"---------Loss curve for epoch {i+1}---------")
#         display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 211)
#         print(f'---------Accuracy curve for epoch {i+1}---------')
#         display_training_curves(history.history['categorical_accuracy'], history.history['val_categorical_accuracy'], 'accuracy', 212)
        
        
        if FIRST_FOLD_ONLY:break
    print(f'Average F1 score for all epochs:{np.average(scores)}')
    return histories,models

# %%
def train_model_predict(folds=5):
    test_dataset=get_test_dataset(ordered=True,do_aug=False)
    test_images_ds=test_dataset.map(lambda image,idnum:image)
    print(f"------Starting Training for Folds {folds}-----")
    histories,models=train_model(folds=folds)
    print(f'-----Computing Prediction---')
     # get the mean probability of the folds models
    if FIRST_FOLD_ONLY: probabilities = np.average([models[i].predict(test_images_ds) for i in range(1)], axis = 0)
    else: probabilities = np.average([models[i].predict(test_images_ds) for i in range(folds)], axis = 0)
    predictions = np.argmax(probabilities, axis=-1)
    print('Generating submission.csv file...')
    test_ids_ds = test_dataset.map(lambda image, idnum: idnum).unbatch()
    test_ids = next(iter(test_ids_ds.batch(NUM_TEST_IMAGES))).numpy().astype('U') # all in one batch
    np.savetxt('submission.csv', np.rec.fromarrays([test_ids, predictions]), fmt=['%s', '%d'], delimiter=',', header='id,label', comments='')
    return histories, models

# %%
# %%time
SEED=101
#model=get_model()
FIRST_FOLD_ONLY = False
FOLDS=5
histories,models=train_model_predict(folds=FOLDS)
# Out:
# ------Starting Training for Folds 5-----
# ---------------Folds 1--------------
# Downloading data from https://github.com/qubvel/efficientnet/releases/download/v0.0.1/efficientnet-b5_noisy-student_notop.h5
# 115261440/115255328 [==============================] - 4s 0us/step
# Training:Doing cutmix augmentation for switch value 0.6281327087844596
# Train for 163 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 1/15
# 163/163 [==============================] - 309s 2s/step - loss: 4.4794 - categorical_accuracy: 0.0552 - val_loss: 4.5848 - val_categorical_accuracy: 0.0408
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 8.8e-05.
# Epoch 2/15
# 163/163 [==============================] - 80s 492ms/step - loss: 3.1708 - categorical_accuracy: 0.3585 - val_loss: 2.4008 - val_categorical_accuracy: 0.5278
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000166.
# Epoch 3/15
# 163/163 [==============================] - 80s 491ms/step - loss: 2.0551 - categorical_accuracy: 0.5851 - val_loss: 0.9498 - val_categorical_accuracy: 0.8219
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.000244.
# Epoch 4/15
# 163/163 [==============================] - 80s 491ms/step - loss: 1.6716 - categorical_accuracy: 0.6415 - val_loss: 0.4516 - val_categorical_accuracy: 0.9314
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000322.
# Epoch 5/15
# 163/163 [==============================] - 80s 490ms/step - loss: 1.4662 - categorical_accuracy: 0.6829 - val_loss: 0.3064 - val_categorical_accuracy: 0.9526
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 6/15
# 163/163 [==============================] - 80s 490ms/step - loss: 1.3584 - categorical_accuracy: 0.7036 - val_loss: 0.2949 - val_categorical_accuracy: 0.9493
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.000322.
# Epoch 7/15
# 163/163 [==============================] - 79s 488ms/step - loss: 1.2254 - categorical_accuracy: 0.7320 - val_loss: 0.2892 - val_categorical_accuracy: 0.9575
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0002596000000000001.
# Epoch 8/15
# 163/163 [==============================] - 80s 491ms/step - loss: 1.1203 - categorical_accuracy: 0.7623 - val_loss: 0.2490 - val_categorical_accuracy: 0.9608
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.00020968000000000004.
# Epoch 9/15
# 163/163 [==============================] - 83s 511ms/step - loss: 1.0528 - categorical_accuracy: 0.7619 - val_loss: 0.1889 - val_categorical_accuracy: 0.9690
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.00016974400000000002.
# Epoch 10/15
# 163/163 [==============================] - 79s 488ms/step - loss: 0.9961 - categorical_accuracy: 0.7588 - val_loss: 0.2085 - val_categorical_accuracy: 0.9657
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.00013779520000000003.
# Epoch 11/15
# 163/163 [==============================] - 80s 490ms/step - loss: 0.9656 - categorical_accuracy: 0.7784 - val_loss: 0.1922 - val_categorical_accuracy: 0.9673
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.00011223616000000004.
# Epoch 12/15
# 163/163 [==============================] - 83s 512ms/step - loss: 0.9336 - categorical_accuracy: 0.7738 - val_loss: 0.1767 - val_categorical_accuracy: 0.9690
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 9.178892800000003e-05.
# Epoch 13/15
# 163/163 [==============================] - 83s 509ms/step - loss: 0.9039 - categorical_accuracy: 0.7791 - val_loss: 0.1737 - val_categorical_accuracy: 0.9690
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 7.543114240000003e-05.
# Epoch 14/15
# 163/163 [==============================] - 83s 507ms/step - loss: 0.8920 - categorical_accuracy: 0.7872 - val_loss: 0.1730 - val_categorical_accuracy: 0.9755
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 6.234491392000002e-05.
# Epoch 15/15
# 163/163 [==============================] - 79s 486ms/step - loss: 0.8707 - categorical_accuracy: 0.7791 - val_loss: 0.1763 - val_categorical_accuracy: 0.9722
# Macro F1 Score for epoch 1: 0.972304902081151
# ---------------Folds 2--------------
# Training:Doing cutmix augmentation for switch value 0.9079694464765431
# Train for 163 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 1/15
# 163/163 [==============================] - 302s 2s/step - loss: 4.5702 - categorical_accuracy: 0.0422 - val_loss: 4.5642 - val_categorical_accuracy: 0.0418
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 8.8e-05.
# Epoch 2/15
# 163/163 [==============================] - 83s 509ms/step - loss: 3.3649 - categorical_accuracy: 0.3248 - val_loss: 1.5786 - val_categorical_accuracy: 0.7729
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000166.
# Epoch 3/15
# 163/163 [==============================] - 83s 509ms/step - loss: 2.0832 - categorical_accuracy: 0.5966 - val_loss: 0.6554 - val_categorical_accuracy: 0.9183
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.000244.
# Epoch 4/15
# 163/163 [==============================] - 83s 507ms/step - loss: 1.6698 - categorical_accuracy: 0.6676 - val_loss: 0.3688 - val_categorical_accuracy: 0.9442
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000322.
# Epoch 5/15
# 163/163 [==============================] - 83s 509ms/step - loss: 1.4808 - categorical_accuracy: 0.6863 - val_loss: 0.2601 - val_categorical_accuracy: 0.9542
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 6/15
# 163/163 [==============================] - 83s 507ms/step - loss: 1.3743 - categorical_accuracy: 0.7132 - val_loss: 0.2275 - val_categorical_accuracy: 0.9482
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.000322.
# Epoch 7/15
# 163/163 [==============================] - 83s 507ms/step - loss: 1.2298 - categorical_accuracy: 0.7469 - val_loss: 0.2071 - val_categorical_accuracy: 0.9661
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0002596000000000001.
# Epoch 8/15
# 163/163 [==============================] - 83s 509ms/step - loss: 1.1388 - categorical_accuracy: 0.7488 - val_loss: 0.1983 - val_categorical_accuracy: 0.9582
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.00020968000000000004.
# Epoch 9/15
# 163/163 [==============================] - 83s 507ms/step - loss: 1.0691 - categorical_accuracy: 0.7600 - val_loss: 0.1785 - val_categorical_accuracy: 0.9701
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.00016974400000000002.
# Epoch 10/15
# 163/163 [==============================] - 79s 485ms/step - loss: 1.0121 - categorical_accuracy: 0.7630 - val_loss: 0.1895 - val_categorical_accuracy: 0.9661
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.00013779520000000003.
# Epoch 11/15
# 163/163 [==============================] - 83s 508ms/step - loss: 0.9787 - categorical_accuracy: 0.7707 - val_loss: 0.1513 - val_categorical_accuracy: 0.9622
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.00011223616000000004.
# Epoch 12/15
# 163/163 [==============================] - 83s 511ms/step - loss: 0.9465 - categorical_accuracy: 0.7914 - val_loss: 0.1500 - val_categorical_accuracy: 0.9741
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 9.178892800000003e-05.
# Epoch 13/15
# 163/163 [==============================] - 83s 509ms/step - loss: 0.9178 - categorical_accuracy: 0.7956 - val_loss: 0.1423 - val_categorical_accuracy: 0.9741
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 7.543114240000003e-05.
# Epoch 14/15
# 163/163 [==============================] - 83s 508ms/step - loss: 0.9062 - categorical_accuracy: 0.7818 - val_loss: 0.1366 - val_categorical_accuracy: 0.9761
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 6.234491392000002e-05.
# Epoch 15/15
# 163/163 [==============================] - 79s 486ms/step - loss: 0.8816 - categorical_accuracy: 0.8025 - val_loss: 0.1367 - val_categorical_accuracy: 0.9741
# Macro F1 Score for epoch 2: 0.9623388298531576
# ---------------Folds 3--------------
# Training:Doing cutmix augmentation for switch value 0.5038257538223936
# Train for 163 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 1/15
# 163/163 [==============================] - 301s 2s/step - loss: 4.5479 - categorical_accuracy: 0.0418 - val_loss: 4.5427 - val_categorical_accuracy: 0.0578
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 8.8e-05.
# Epoch 2/15
# 163/163 [==============================] - 82s 505ms/step - loss: 3.3387 - categorical_accuracy: 0.3370 - val_loss: 2.0098 - val_categorical_accuracy: 0.5956
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000166.
# Epoch 3/15
# 163/163 [==============================] - 83s 508ms/step - loss: 2.0779 - categorical_accuracy: 0.5855 - val_loss: 0.7660 - val_categorical_accuracy: 0.8466
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.000244.
# Epoch 4/15
# 163/163 [==============================] - 83s 507ms/step - loss: 1.6456 - categorical_accuracy: 0.6637 - val_loss: 0.4878 - val_categorical_accuracy: 0.9124
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000322.
# Epoch 5/15
# 163/163 [==============================] - 83s 507ms/step - loss: 1.4428 - categorical_accuracy: 0.6821 - val_loss: 0.2951 - val_categorical_accuracy: 0.9402
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 6/15
# 163/163 [==============================] - 79s 487ms/step - loss: 1.3594 - categorical_accuracy: 0.7159 - val_loss: 0.4084 - val_categorical_accuracy: 0.9024
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.000322.
# Epoch 7/15
# 163/163 [==============================] - 83s 507ms/step - loss: 1.2225 - categorical_accuracy: 0.7412 - val_loss: 0.2745 - val_categorical_accuracy: 0.9522
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0002596000000000001.
# Epoch 8/15
# 163/163 [==============================] - 83s 508ms/step - loss: 1.1290 - categorical_accuracy: 0.7581 - val_loss: 0.2211 - val_categorical_accuracy: 0.9602
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.00020968000000000004.
# Epoch 9/15
# 163/163 [==============================] - 83s 510ms/step - loss: 1.0591 - categorical_accuracy: 0.7550 - val_loss: 0.1981 - val_categorical_accuracy: 0.9741
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.00016974400000000002.
# Epoch 10/15
# 163/163 [==============================] - 80s 488ms/step - loss: 1.0056 - categorical_accuracy: 0.7673 - val_loss: 0.1981 - val_categorical_accuracy: 0.9681
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.00013779520000000003.
# Epoch 11/15
# 163/163 [==============================] - 83s 509ms/step - loss: 0.9667 - categorical_accuracy: 0.7665 - val_loss: 0.1962 - val_categorical_accuracy: 0.9681
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.00011223616000000004.
# Epoch 12/15
# 163/163 [==============================] - 83s 510ms/step - loss: 0.9343 - categorical_accuracy: 0.7588 - val_loss: 0.1645 - val_categorical_accuracy: 0.9681
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 9.178892800000003e-05.
# Epoch 13/15
# 163/163 [==============================] - 83s 509ms/step - loss: 0.9076 - categorical_accuracy: 0.7730 - val_loss: 0.1597 - val_categorical_accuracy: 0.9701
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 7.543114240000003e-05.
# Epoch 14/15
# 163/163 [==============================] - 83s 509ms/step - loss: 0.8922 - categorical_accuracy: 0.7841 - val_loss: 0.1535 - val_categorical_accuracy: 0.9721
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 6.234491392000002e-05.
# Epoch 15/15
# 163/163 [==============================] - 79s 484ms/step - loss: 0.8724 - categorical_accuracy: 0.7818 - val_loss: 0.1587 - val_categorical_accuracy: 0.9761
# Macro F1 Score for epoch 3: 0.954425441076647
# ---------------Folds 4--------------
# Training:Doing cutmix augmentation for switch value 0.6511179479432686
# Train for 163 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 1/15
# 163/163 [==============================] - 300s 2s/step - loss: 4.5234 - categorical_accuracy: 0.0483 - val_loss: 4.5063 - val_categorical_accuracy: 0.0598
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 8.8e-05.
# Epoch 2/15
# 163/163 [==============================] - 80s 494ms/step - loss: 3.3725 - categorical_accuracy: 0.3117 - val_loss: 1.9171 - val_categorical_accuracy: 0.5657
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000166.
# Epoch 3/15
# 163/163 [==============================] - 80s 492ms/step - loss: 2.0869 - categorical_accuracy: 0.5863 - val_loss: 0.7047 - val_categorical_accuracy: 0.8526
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.000244.
# Epoch 4/15
# 163/163 [==============================] - 81s 495ms/step - loss: 1.6458 - categorical_accuracy: 0.6492 - val_loss: 0.4290 - val_categorical_accuracy: 0.8944
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000322.
# Epoch 5/15
# 163/163 [==============================] - 80s 493ms/step - loss: 1.4560 - categorical_accuracy: 0.6917 - val_loss: 0.3181 - val_categorical_accuracy: 0.9263
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 6/15
# 163/163 [==============================] - 81s 496ms/step - loss: 1.3633 - categorical_accuracy: 0.7201 - val_loss: 0.3113 - val_categorical_accuracy: 0.9104
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.000322.
# Epoch 7/15
# 163/163 [==============================] - 80s 491ms/step - loss: 1.2343 - categorical_accuracy: 0.7404 - val_loss: 0.2597 - val_categorical_accuracy: 0.9143
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0002596000000000001.
# Epoch 8/15
# 163/163 [==============================] - 81s 494ms/step - loss: 1.1182 - categorical_accuracy: 0.7527 - val_loss: 0.2355 - val_categorical_accuracy: 0.9343
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.00020968000000000004.
# Epoch 9/15
# 163/163 [==============================] - 80s 492ms/step - loss: 1.0660 - categorical_accuracy: 0.7492 - val_loss: 0.1883 - val_categorical_accuracy: 0.9502
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.00016974400000000002.
# Epoch 10/15
# 163/163 [==============================] - 77s 475ms/step - loss: 1.0064 - categorical_accuracy: 0.7653 - val_loss: 0.2151 - val_categorical_accuracy: 0.9343
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.00013779520000000003.
# Epoch 11/15
# 163/163 [==============================] - 77s 475ms/step - loss: 0.9718 - categorical_accuracy: 0.7749 - val_loss: 0.1884 - val_categorical_accuracy: 0.9482
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.00011223616000000004.
# Epoch 12/15
# 163/163 [==============================] - 80s 493ms/step - loss: 0.9437 - categorical_accuracy: 0.7715 - val_loss: 0.1658 - val_categorical_accuracy: 0.9442
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 9.178892800000003e-05.
# Epoch 13/15
# 163/163 [==============================] - 80s 493ms/step - loss: 0.9154 - categorical_accuracy: 0.7891 - val_loss: 0.1595 - val_categorical_accuracy: 0.9562
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 7.543114240000003e-05.
# Epoch 14/15
# 163/163 [==============================] - 81s 495ms/step - loss: 0.8936 - categorical_accuracy: 0.7803 - val_loss: 0.1581 - val_categorical_accuracy: 0.9582
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 6.234491392000002e-05.
# Epoch 15/15
# 163/163 [==============================] - 77s 473ms/step - loss: 0.8785 - categorical_accuracy: 0.7830 - val_loss: 0.1673 - val_categorical_accuracy: 0.9502
# Macro F1 Score for epoch 4: 0.9506768566077555
# ---------------Folds 5--------------
# Training:Doing rotation transformation for switch value -0.31931804459303326
# Train for 163 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 1/15
# 163/163 [==============================] - 323s 2s/step - loss: 4.4489 - sparse_categorical_accuracy: 0.0660 - val_loss: 4.4643 - val_sparse_categorical_accuracy: 0.1235
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 8.8e-05.
# Epoch 2/15
# 163/163 [==============================] - 90s 549ms/step - loss: 2.2708 - sparse_categorical_accuracy: 0.5245 - val_loss: 1.3180 - val_sparse_categorical_accuracy: 0.7032
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.000166.
# Epoch 3/15
# 163/163 [==============================] - 85s 521ms/step - loss: 0.5108 - sparse_categorical_accuracy: 0.8604 - val_loss: 0.3246 - val_sparse_categorical_accuracy: 0.9343
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.000244.
# Epoch 4/15
# 163/163 [==============================] - 89s 548ms/step - loss: 0.2625 - sparse_categorical_accuracy: 0.9363 - val_loss: 0.2110 - val_sparse_categorical_accuracy: 0.9502
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.000322.
# Epoch 5/15
# 163/163 [==============================] - 89s 548ms/step - loss: 0.1943 - sparse_categorical_accuracy: 0.9540 - val_loss: 0.2153 - val_sparse_categorical_accuracy: 0.9522
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 6/15
# 163/163 [==============================] - 85s 520ms/step - loss: 0.1771 - sparse_categorical_accuracy: 0.9574 - val_loss: 0.2402 - val_sparse_categorical_accuracy: 0.9402
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.000322.
# Epoch 7/15
# 163/163 [==============================] - 88s 540ms/step - loss: 0.1072 - sparse_categorical_accuracy: 0.9678 - val_loss: 0.1839 - val_sparse_categorical_accuracy: 0.9602
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0002596000000000001.
# Epoch 8/15
# 163/163 [==============================] - 83s 509ms/step - loss: 0.0695 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1717 - val_sparse_categorical_accuracy: 0.9701
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.00020968000000000004.
# Epoch 9/15
# 163/163 [==============================] - 93s 569ms/step - loss: 0.0445 - sparse_categorical_accuracy: 0.9885 - val_loss: 0.1459 - val_sparse_categorical_accuracy: 0.9741
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.00016974400000000002.
# Epoch 10/15
# 163/163 [==============================] - 86s 527ms/step - loss: 0.0337 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.1618 - val_sparse_categorical_accuracy: 0.9761
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.00013779520000000003.
# Epoch 11/15
# 163/163 [==============================] - 85s 521ms/step - loss: 0.0266 - sparse_categorical_accuracy: 0.9908 - val_loss: 0.1626 - val_sparse_categorical_accuracy: 0.9761
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.00011223616000000004.
# Epoch 12/15
# 163/163 [==============================] - 83s 508ms/step - loss: 0.0217 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.1491 - val_sparse_categorical_accuracy: 0.9781
# Epoch 00012: early stopping
# Macro F1 Score for epoch 5: 0.9666233350196921
# Average F1 score for all epochs:0.9612738729276806
# -----Computing Prediction---
# Generating submission.csv file...
# CPU times: user 26min 14s, sys: 2min 41s, total: 28min 56s
# Wall time: 2h 12min 23s
